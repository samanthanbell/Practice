# %%
import pandas as pd

# %%
bookings=pd.read_csv("C:/Users/bellcsa/OneDrive - Lam Research/DataScience/gits/Python/hotel_bookings.csv")
bookings.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  MonthNo    DateNo  \
# 0                        27                          1        7  7/1/2015
# 1                        27                          1        7  7/1/2015
# 2                        27                          1        7  7/1/2015
# 3                        27                          1        7  7/1/2015
# 4                        27                          1        7  7/1/2015
#
# ...

# %%
bookings.fillna({'children' : 0, 'country' : '0', 'agent' : 0, 'company' : 0}, inplace = True)
